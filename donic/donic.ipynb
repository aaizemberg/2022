# %%
import pandas as pd

# %%
df = pd.read_csv('donic.tsv', sep='\t')

# %%
df.head()
# Out:
#                 Name  Speed  Spin  Tackiness  Overall  Price  \
# 0     Donic Baracuda    8.7   9.5        2.3      9.3     40
# 1     Donic Acuda S2    8.8   9.1        2.6      9.2     37
# 2  Donic Bluefire M1    9.3   9.3        2.7      9.3     54
# 3     Donic Acuda S3    8.4   9.1        1.8      9.0     52
# 4     Donic Acuda S1    9.2   9.2        1.9      9.2     52
#
#            Ratings
# 0                             198
# 1                             108
# 2                              81
# 3                              73
# 4                              56

# %%
df.tail()
# Out:
#                       Name  Speed  Spin  Tackiness  Overall  Price  \
# 79              Donic Solo    7.0   7.5        2.0      7.9     12
# 80       Donic Traction II    8.5   9.3        5.0      9.2     54
# 81      Donic Vario Mach 1    9.0   8.0        2.0      7.0     36
# 82       Donic Vario Sound    9.0   8.0        2.0      8.0     59
# 83  Donic Vario ST (Tuned)    7.9   8.8        0.0      7.6     38
#
#             Ratings
# 79                               1
# 80                               1
# 81                               1
# 82                               1
# 83                               1
